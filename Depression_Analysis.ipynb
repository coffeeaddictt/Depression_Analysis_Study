# %% [markdown]
# ## **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import warnings 
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## **Running the Carbon Tracker**

# %%
# %run carbon_tracker.py

# %% [markdown]
# ## **Loading Dataset**

# %%
update_project_name("Depression_Analysis.ipynb")

data = pd.read_csv('final_depression_dataset_1.csv')
# Out:
# [codecarbon ERROR @ 10:27:27] You first need to start the tracker.

# %%
# HEAD OF DATA
data.head(2)
# Out:
#       Name  Gender  Age       City Working Professional or Student  \
# 0    Pooja  Female   37  Ghaziabad            Working Professional
# 1  Reyansh    Male   60     Kalyan            Working Professional
#
#           Profession  Academic Pressure  Work Pressure  CGPA  \
# 0            Teacher                NaN            2.0   NaN
# 1  Financial Analyst                NaN            4.0   NaN
#
#    Study Satisfaction  Job Satisfaction Sleep Duration Dietary Habits Degree  \
# 0                 NaN               4.0      7-8 hours       Moderate     MA
# 1                 NaN               3.0      5-6 hours      Unhealthy  B.Com
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    No                 6                 2
# 1                                   Yes                 0                 4
#
#   Family History of Mental Illness Depression
# 0                               No         No
# 1                              Yes         No

# %%
# COUNT ROWS AND COLUMNS
print(f'''NUMBER OF ROWS = {data.shape[0]}
NUMBER OF COLUMNS = {data.shape[1]}''')
# Out:
# NUMBER OF ROWS = 2556
# NUMBER OF COLUMNS = 19

# %% [markdown]
# ### **Basic Data Information**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2556 entries, 0 to 2555
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Name                                   2556 non-null   object
#  1   Gender                                 2556 non-null   object
#  2   Age                                    2556 non-null   int64
#  3   City                                   2556 non-null   object
#  4   Working Professional or Student        2556 non-null   object
#  5   Profession                             1883 non-null   object
#  6   Academic Pressure                      502 non-null    float64
#  7   Work Pressure                          2054 non-null   float64
#  8   CGPA                                   502 non-null    float64
#  9   Study Satisfaction                     502 non-null    float64
#  10  Job Satisfaction                       2054 non-null   float64
#  11  Sleep Duration                         2556 non-null   object
#  12  Dietary Habits                         2556 non-null   object
#  13  Degree                                 2556 non-null   object
#  14  Have you ever had suicidal thoughts ?  2556 non-null   object
#  15  Work/Study Hours                       2556 non-null   int64
#  16  Financial Stress                       2556 non-null   int64
#  17  Family History of Mental Illness       2556 non-null   object
#  18  Depression                             2556 non-null   object
# dtypes: float64(5), int64(3), object(11)
# memory usage: 379.5+ KB

# %% [markdown]
# ### **Descriptive Analysis**

# %%
data.describe().T # Numerical values
# Out:
#                      count       mean        std    min    25%     50%  \
# Age                 2556.0  39.043036  12.260596  18.00  28.00  39.000
# Academic Pressure    502.0   3.003984   1.390007   1.00   2.00   3.000
# Work Pressure       2054.0   3.021908   1.417312   1.00   2.00   3.000
# CGPA                 502.0   7.567809   1.465367   5.03   6.21   7.605
# Study Satisfaction   502.0   3.075697   1.373490   1.00   2.00   3.000
# Job Satisfaction    2054.0   3.015093   1.418432   1.00   2.00   3.000
# Work/Study Hours    2556.0   6.023865   3.771743   0.00   3.00   6.000
# Financial Stress    2556.0   2.968701   1.415527   1.00   2.00   3.000
#
#                        75%   max
# Age                 50.000  60.0
# Academic Pressure    4.000   5.0
# Work Pressure        4.000   5.0
# CGPA                 8.825  10.0
# Study Satisfaction   4.000   5.0
# Job Satisfaction     4.000   5.0
# Work/Study Hours     9.000  12.0
# Financial Stress     4.000   5.0

# %%
# DEFINING CATEGORICAL COLUMN
data.describe(include=object).T #  categorial columns
# Out:
#                                       count unique                   top  freq
# Name                                   2556    216                 Rohan    26
# Gender                                 2556      2                  Male  1333
# City                                   2556     30              Srinagar   102
# Working Professional or Student        2556      2  Working Professional  2054
# Profession                             1883     35               Teacher   322
# Sleep Duration                         2556      4             7-8 hours   658
# Dietary Habits                         2556      3             Unhealthy   882
# Degree                                 2556     27              Class 12   275
# Have you ever had suicidal thoughts ?  2556      2                    No  1307
# Family History of Mental Illness       2556      2                    No  1311
# Depression                             2556      2                    No  2101

# %%
data.isnull().sum()
# Out:
# Name                                        0
# Gender                                      0
# Age                                         0
# City                                        0
# Working Professional or Student             0
# Profession                                673
# Academic Pressure                        2054
# Work Pressure                             502
# CGPA                                     2054
# Study Satisfaction                       2054
# Job Satisfaction                          502
# Sleep Duration                              0
# Dietary Habits                              0
# Degree                                      0
# Have you ever had suicidal thoughts ?       0
# Work/Study Hours                            0
# Financial Stress                            0
# Family History of Mental Illness            0
# Depression                                  0
# dtype: int64

# %% [raw]
# Notes:
# Work pressure and job satisfaction have 502 null values, indicating that these 502 individuals are students.
# Academic pressure, cgpa, and study satisfaction have 2054 null values, indicating that these 2054 individuals are working professionals.

# %% [markdown]
# ## **Correlation**

# %%
# EXPLORING THE CORRELATION BETWEEN ALL THE NUMERIC COLUMNS VIA HEATMAP
update_project_name("Depression_Analysis.ipynb")
plt.figure(figsize = (10,8))
sns.heatmap(data=data.corr(numeric_only=True), vmin = -1, vmax = 1, annot = True, cmap = 'BuPu', linecolor= 'black')
# Out:
# <Axes: >

# %% [markdown]
# ## **Data Visualisation**

# %%
data.tail()
# Out:
#              Name  Gender  Age       City Working Professional or Student  \
# 2551  Raghavendra    Male   25  Bangalore            Working Professional
# 2552         Pihu  Female   23       Pune            Working Professional
# 2553         Sara  Female   24   Srinagar            Working Professional
# 2554       Eshita  Female   56  Bangalore            Working Professional
# 2555        Kiran    Male   18      Surat                         Student
#
#             Profession  Academic Pressure  Work Pressure  CGPA  \
# 2551        Consultant                NaN            1.0   NaN
# 2552           Teacher                NaN            3.0   NaN
# 2553        HR Manager                NaN            1.0   NaN
# 2554  Business Analyst                NaN            2.0   NaN
# 2555               NaN                5.0            NaN   6.7
#
#       Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 2551                 NaN               5.0          5-6 hours        Healthy
# 2552                 NaN               1.0  Less than 5 hours       Moderate
# 2553                 NaN               4.0  Less than 5 hours       Moderate
# 2554                 NaN               3.0          7-8 hours        Healthy
# 2555                 3.0               NaN  More than 8 hours      Unhealthy
#
#         Degree Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 2551       BBA                                   Yes                12
# 2552        MA                                   Yes                 8
# 2553        BA                                   Yes                 4
# 2554       BBA                                    No                 4
# 2555  Class 12                                    No                 6
#
#       Financial Stress Family History of Mental Illness Depression
# 2551                 3                              Yes         No
# 2552                 3                               No        Yes
# 2553                 4                               No         No
# 2554                 5                              Yes         No
# 2555                 2                              Yes        Yes

# %% [raw]
# Let's break this data into two parts based on occupation, whether the individual is a working professional or a student, to get a clearer picture of the data.

# %%
data_wp = data[data['Working Professional or Student'] == 'Working Professional']

# %% [raw]
# data_wp refers to data of working professionals, it has some unwanted columns as well like CGPA, Academic Pressure and study satisfaction
# so we can easily drop them

# %%
data_wp = data_wp.drop(columns = ['Study Satisfaction', 'Academic Pressure','CGPA'])

# %%
data_wp.tail()
# Out:
#              Name  Gender  Age       City Working Professional or Student  \
# 2550       Prisha  Female   45   Srinagar            Working Professional
# 2551  Raghavendra    Male   25  Bangalore            Working Professional
# 2552         Pihu  Female   23       Pune            Working Professional
# 2553         Sara  Female   24   Srinagar            Working Professional
# 2554       Eshita  Female   56  Bangalore            Working Professional
#
#             Profession  Work Pressure  Job Satisfaction     Sleep Duration  \
# 2550           Teacher            1.0               3.0  Less than 5 hours
# 2551        Consultant            1.0               5.0          5-6 hours
# 2552           Teacher            3.0               1.0  Less than 5 hours
# 2553        HR Manager            1.0               4.0  Less than 5 hours
# 2554  Business Analyst            2.0               3.0          7-8 hours
#
#      Dietary Habits Degree Have you ever had suicidal thoughts ?  \
# 2550        Healthy    LLM                                   Yes
# 2551        Healthy    BBA                                   Yes
# 2552       Moderate     MA                                   Yes
# 2553       Moderate     BA                                   Yes
# 2554        Healthy    BBA                                    No
#
#       Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 2550                 2                 5                              Yes
# 2551                12                 3                              Yes
# 2552                 8                 3                               No
# 2553                 4                 4                               No
# 2554                 4                 5                              Yes
#
#      Depression
# 2550         No
# 2551         No
# 2552        Yes
# 2553         No
# 2554         No

# %%
data_wp.isnull().sum()
# Out:
# Name                                       0
# Gender                                     0
# Age                                        0
# City                                       0
# Working Professional or Student            0
# Profession                               171
# Work Pressure                              0
# Job Satisfaction                           0
# Sleep Duration                             0
# Dietary Habits                             0
# Degree                                     0
# Have you ever had suicidal thoughts ?      0
# Work/Study Hours                           0
# Financial Stress                           0
# Family History of Mental Illness           0
# Depression                                 0
# dtype: int64

# %%
data_stud = data[data['Working Professional or Student'] == 'Student']

# %% [raw]
# data_stud refers to data of student, it has some unwanted columns as well like Profession, Work Pressure and job satisfaction
# so we can easily drop them

# %%
data_stud = data_stud.drop(columns = ['Job Satisfaction', 'Work Pressure','Profession'])

# %%
data_stud.tail()
# Out:
#            Name  Gender  Age    City Working Professional or Student  \
# 2525  Siddharth    Male   26  Indore                         Student
# 2538     Nikhil    Male   24  Jaipur                         Student
# 2539      Rashi  Female   23  Bhopal                         Student
# 2545      Rupak    Male   33    Agra                         Student
# 2555      Kiran    Male   18   Surat                         Student
#
#       Academic Pressure   CGPA  Study Satisfaction     Sleep Duration  \
# 2525                5.0  10.00                 2.0  More than 8 hours
# 2538                2.0   6.39                 1.0  Less than 5 hours
# 2539                3.0   8.46                 5.0          5-6 hours
# 2545                4.0   6.89                 4.0  More than 8 hours
# 2555                5.0   6.70                 3.0  More than 8 hours
#
#      Dietary Habits    Degree Have you ever had suicidal thoughts ?  \
# 2525      Unhealthy     B.Com                                    No
# 2538      Unhealthy       MCA                                   Yes
# 2539        Healthy       MBA                                    No
# 2545        Healthy    B.Arch                                    No
# 2555      Unhealthy  Class 12                                    No
#
#       Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 2525                 8                 3                               No
# 2538                 8                 5                               No
# 2539                 1                 5                              Yes
# 2545                 8                 1                              Yes
# 2555                 6                 2                              Yes
#
#      Depression
# 2525        Yes
# 2538        Yes
# 2539         No
# 2545         No
# 2555        Yes

# %%
data_stud.isnull().sum()
# Out:
# Name                                     0
# Gender                                   0
# Age                                      0
# City                                     0
# Working Professional or Student          0
# Academic Pressure                        0
# CGPA                                     0
# Study Satisfaction                       0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %% [markdown]
# So now, this does not have any null values in any of the columns.

# %%
#Target Variable Analysis (Depression) ----
# Check class balance for the target variable
print(data_wp['Depression'].value_counts(normalize=True))
sns.countplot(x='Depression', data=data_wp)
plt.title('Depression Class Distribution')
plt.show()
# Out:
# Depression
# No     0.901168
# Yes    0.098832
# Name: proportion, dtype: float64

# %% [markdown]
# # **Univariate Analysis of Students Data**

# %%
# Separate the numerical and categorical columns
update_project_name("Depression_Analysis.ipynb")

data_stud.columns

num_col = ['Age','Work/Study Hours','CGPA']
cat_col = ['Gender','Academic Pressure','Study Satisfaction', 'Sleep Duration',
       'Dietary Habits', 'Have you ever had suicidal thoughts ?',
       'Work/Study Hours', 'Financial Stress', 'Depression']

# %%
# Explore the numerical column via boxplot
t = 1
plt.figure(figsize = (10,10))
plt.suptitle('UNIVARIATE ANALYSIS NUMERICAL COLUMNS', fontsize = 20, color = 'Black')
for i in num_col:
    s,k = data_stud[i].skew(), data_stud[i].kurt()
    plt.subplot(3,1,t)
    sns.boxplot(data = data_stud, x = i, fill = True, color = 'maroon')
    plt.title(f'SKEWNESS : {s}, KURTOSIS : {k}')
    t = t+1

plt.tight_layout()
plt.show()

# %%
# Explore the categorical column by CountPlot
t =1
plt.figure(figsize = (20,18))
plt.suptitle('UNIVARIATE ANALYSIS OF CATEGORICAL COLUMNS', fontsize= 20, color = 'Black')
for i in cat_col:
    plt.subplot(6,2,t)
    sns.countplot(data = data_stud, x = i, palette=['pink', 'aqua','maroon', 'brown', 'grey', 'yellow', 'green', 'orange', 'black', 'gold'])
    plt.xticks(rotation = 90)
    t = t+1

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Univariate Analysis of Working Professionals Data**

# %%
# Separate the numerical and categorical columns
update_project_name("Depression_Analysis.ipynb")
data_wp.columns

num_cols = ['Age','Work/Study Hours']
cat_cols = ['Gender','Work Pressure','Job Satisfaction', 'Sleep Duration',
       'Dietary Habits', 'Have you ever had suicidal thoughts ?',
       'Financial Stress',
       'Family History of Mental Illness', 'Depression']

# %%
# Explore the numerical column via boxplot
t = 1
plt.figure(figsize = (10,5))
plt.suptitle('UNIVARIATE ANALYSIS NUMERICAL COLUMNS', fontsize = 20, color = 'Black')
for i in num_cols:
    s,k = data_wp[i].skew(), data_wp[i].kurt()
    plt.subplot(2,1,t)
    sns.boxplot(data = data_wp, x = i, fill = True, color = 'maroon')
    plt.title(f'SKEWNESS : {s}, KURTOSIS : {k}')
    t = t+1

plt.tight_layout()
plt.show()

# %%
# Explore the categorical column by CountPlot
t =1
plt.figure(figsize = (20,18))
plt.suptitle('UNIVARIATE ANALYSIS OF CATEGORICAL COLUMNS', fontsize= 20, color = 'Black')
for i in cat_cols:
    plt.subplot(7,2,t)
    sns.countplot(data = data_wp, x = i, palette=['pink', 'aqua','red', 'brown', 'grey', 'yellow', 'green', 'orange', 'blue', 'gold'])
    plt.xticks(rotation = 90)
    t = t+1

plt.tight_layout()
plt.show()

# %%
# Set up the figure and layout
t = 1
plt.figure(figsize=(25, 20))
plt.suptitle('UNIVARIATE ANALYSIS OF CATEGORICAL COLUMNS', fontsize=20, color='Black')

# Loop through each categorical column to create pie charts
for i in cat_cols:
    plt.subplot(9, 1, t)  # Adjust grid size based on number of columns
    data_wp[i].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, 
        colors=['pink', 'lightblue', 'red', 'brown', 'grey', 'yellow', 'green', 'orange', 'blue', 'gold'])
    plt.title(i)  # Set title to the column name
    plt.ylabel('')  # Remove y-axis label for a cleaner look
    t += 1

plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to fit the suptitle
plt.show()

# %% [markdown]
# # **Bivariate Analysis**

# %%
features = ['Work Pressure','Job Satisfaction', 'Sleep Duration','Dietary Habits', 'Have you ever had suicidal thoughts ?',
       'Financial Stress','Family History of Mental Illness']

# %%
# Loop through each feature and create a stacked bar plot for 'Depression' by each feature
for feature in features:
    cross_tab = pd.crosstab(data_wp[feature], data_wp['Depression'], normalize='index')
    
    cross_tab.plot(kind='bar', stacked=True, color=['pink', 'lightblue', 'red', 'brown'])

    plt.title(f'Depression by {feature}')
    plt.xlabel(feature)
    plt.ylabel('Proportion')
    
    plt.show()

# %% [markdown]
# Notes :
# 1. A family history of mental illness is not related to an individual's depression.
# 2. Higher financial stress increases the chances of depression.
# 3. Most depressed individuals experience suicidal thoughts.
# 4. Depressed individuals tend to have an unhealthy diet.
# 5. Greater work pressure raises the likelihood of depression.
# 6. Most depressed individuals have low job satisfaction.

# %% [markdown]
# # **BIVARIATE ANALYSIS OF STUDENT'S DATA**

# %%
feat = ['Academic Pressure','Study Satisfaction', 'Sleep Duration','Dietary Habits', 'Have you ever had suicidal thoughts ?',
            'Financial Stress','Family History of Mental Illness']

# %%
for feature in feat:
    cross_tab = pd.crosstab(data_stud[feature], data_stud['Depression'], normalize='index')
    
    cross_tab.plot(kind='bar', stacked=True, color=['pink', 'red'])

    plt.title(f'Depression by {feature}')
    plt.xlabel(feature)
    plt.ylabel('Proportion')
    
    plt.show()

# %% [markdown]
# Notes:<br>
# 1- Family history of mental illness is not directly related to an individual's depression.<br>
# 2- Higher financial stress increases the likelihood of depression.<br>
# 3- Most individuals experiencing depression have suicidal thoughts.<br>
# 4- Depressed individuals tend to have an unhealthy diet.<br>
# 5- Increased academic pressure raises the chances of depression.<br>
# 6- Depressed individuals often have low study satisfaction.

# %% [markdown]
# ## **NULL VALUE TREATMENT**

# %%
update_project_name("Depression_Analysis.ipynb")
data.head()
# Out:
#       Name  Gender  Age       City Working Professional or Student  \
# 0    Pooja  Female   37  Ghaziabad            Working Professional
# 1  Reyansh    Male   60     Kalyan            Working Professional
# 2    Manvi  Female   42     Bhopal            Working Professional
# 3     Isha  Female   44      Thane            Working Professional
# 4    Aarav    Male   48     Indore            Working Professional
#
#           Profession  Academic Pressure  Work Pressure  CGPA  \
# 0            Teacher                NaN            2.0   NaN
# 1  Financial Analyst                NaN            4.0   NaN
# 2            Teacher                NaN            2.0   NaN
# 3            Teacher                NaN            3.0   NaN
# 4     UX/UI Designer                NaN            4.0   NaN
#
#    Study Satisfaction  Job Satisfaction Sleep Duration Dietary Habits Degree  \
# 0                 NaN               4.0      7-8 hours       Moderate     MA
# 1                 NaN               3.0      5-6 hours      Unhealthy  B.Com
# 2                 NaN               3.0      5-6 hours       Moderate  M.Com
# 3                 NaN               5.0      7-8 hours        Healthy     MD
# 4                 NaN               3.0      7-8 hours       Moderate     BE
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    No                 6                 2
# 1                                   Yes                 0                 4
# 2                                    No                 0                 2
# 3                                   Yes                 1                 2
# 4                                   Yes                 6                 5
#
#   Family History of Mental Illness Depression
# 0                               No         No
# 1                              Yes         No
# 2                               No         No
# 3                              Yes         No
# 4                              Yes         No

# %%
data['Academic Pressure'] = data['Academic Pressure'].fillna(0)
data['Study Satisfaction'] = data['Study Satisfaction'].fillna(0)
data['Work Pressure'] = data['Work Pressure'].fillna(0)
data['Job Satisfaction'] = data['Job Satisfaction'].fillna(0)
data['Financial Stress'] = data['Financial Stress'].fillna(0)
data['CGPA'] = data['CGPA'].fillna(0)

# %%
data.head()
# Out:
#       Name  Gender  Age       City Working Professional or Student  \
# 0    Pooja  Female   37  Ghaziabad            Working Professional
# 1  Reyansh    Male   60     Kalyan            Working Professional
# 2    Manvi  Female   42     Bhopal            Working Professional
# 3     Isha  Female   44      Thane            Working Professional
# 4    Aarav    Male   48     Indore            Working Professional
#
#           Profession  Academic Pressure  Work Pressure  CGPA  \
# 0            Teacher                0.0            2.0   0.0
# 1  Financial Analyst                0.0            4.0   0.0
# 2            Teacher                0.0            2.0   0.0
# 3            Teacher                0.0            3.0   0.0
# 4     UX/UI Designer                0.0            4.0   0.0
#
#    Study Satisfaction  Job Satisfaction Sleep Duration Dietary Habits Degree  \
# 0                 0.0               4.0      7-8 hours       Moderate     MA
# 1                 0.0               3.0      5-6 hours      Unhealthy  B.Com
# 2                 0.0               3.0      5-6 hours       Moderate  M.Com
# 3                 0.0               5.0      7-8 hours        Healthy     MD
# 4                 0.0               3.0      7-8 hours       Moderate     BE
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    No                 6                 2
# 1                                   Yes                 0                 4
# 2                                    No                 0                 2
# 3                                   Yes                 1                 2
# 4                                   Yes                 6                 5
#
#   Family History of Mental Illness Depression
# 0                               No         No
# 1                              Yes         No
# 2                               No         No
# 3                              Yes         No
# 4                              Yes         No

# %% [markdown]
# All the null values are treated now, except for the profession column.

# %% [markdown]
# ## **FEATURE CREATION**

# %%
update_project_name("Depression_Analysis.ipynb")
data['Work/Acadmic Pressure'] = data['Academic Pressure'] + data['Work Pressure']
data['Study/Job Satisfaction'] = data['Study Satisfaction'] + data['Job Satisfaction']

# %%
data.head()
# Out:
#       Name  Gender  Age       City Working Professional or Student  \
# 0    Pooja  Female   37  Ghaziabad            Working Professional
# 1  Reyansh    Male   60     Kalyan            Working Professional
# 2    Manvi  Female   42     Bhopal            Working Professional
# 3     Isha  Female   44      Thane            Working Professional
# 4    Aarav    Male   48     Indore            Working Professional
#
#           Profession  Academic Pressure  Work Pressure  CGPA  \
# 0            Teacher                0.0            2.0   0.0
# 1  Financial Analyst                0.0            4.0   0.0
# 2            Teacher                0.0            2.0   0.0
# 3            Teacher                0.0            3.0   0.0
# 4     UX/UI Designer                0.0            4.0   0.0
#
#    Study Satisfaction  ...  Sleep Duration Dietary Habits Degree  \
# 0                 0.0  ...       7-8 hours       Moderate     MA
# 1                 0.0  ...       5-6 hours      Unhealthy  B.Com
# 2                 0.0  ...       5-6 hours       Moderate  M.Com
# 3                 0.0  ...       7-8 hours        Healthy     MD
# 4                 0.0  ...       7-8 hours       Moderate     BE
#
#   Have you ever had suicidal thoughts ? Work/Study Hours  Financial Stress  \
# 0                                    No                6                 2
# 1                                   Yes                0                 4
# 2                                    No                0                 2
# 3                                   Yes                1                 2
# 4                                   Yes                6                 5
#
#    Family History of Mental Illness Depression Work/Acadmic Pressure  \
# 0                                No         No                   2.0
# 1                               Yes         No                   4.0
# 2                                No         No                   2.0
# 3                               Yes         No                   3.0
# 4                               Yes         No                   4.0
#
#    Study/Job Satisfaction
# 0                     4.0
# 1                     3.0
# 2                     3.0
# 3                     5.0
# 4                     3.0
#
# [5 rows x 21 columns]

# %%
data.isnull().sum()
# Out:
# Name                                       0
# Gender                                     0
# Age                                        0
# City                                       0
# Working Professional or Student            0
# Profession                               673
# Academic Pressure                          0
# Work Pressure                              0
# CGPA                                       0
# Study Satisfaction                         0
# Job Satisfaction                           0
# Sleep Duration                             0
# Dietary Habits                             0
# Degree                                     0
# Have you ever had suicidal thoughts ?      0
# Work/Study Hours                           0
# Financial Stress                           0
# Family History of Mental Illness           0
# Depression                                 0
# Work/Acadmic Pressure                      0
# Study/Job Satisfaction                     0
# dtype: int64

# %% [markdown]
# ## **DATA PREPROCESSING**

# %%
data['Profession'].unique()
# Out:
# array(['Teacher', 'Financial Analyst', 'UX/UI Designer', 'Civil Engineer',
#        'Accountant', 'Lawyer', 'Content Writer', nan, 'Pilot',
#        'Customer Support', 'Judge', 'Architect', 'HR Manager',
#        'Digital Marketer', 'Sales Executive', 'Business Analyst',
#        'Mechanical Engineer', 'Consultant', 'Data Scientist',
#        'Pharmacist', 'Software Engineer', 'Travel Consultant', 'Manager',
#        'Entrepreneur', 'Doctor', 'Researcher', 'Plumber',
#        'Finanancial Analyst', 'Marketing Manager',
#        'Educational Consultant', 'Chemist', 'Research Analyst', 'Chef',
#        'Electrician', 'Graphic Designer', 'Investment Banker'],
#       dtype=object)

# %%
chi2contingency = pd.crosstab(data['Profession'], data['Depression'])
chi2contingency
# Out:
# Depression               No  Yes
# Profession
# Accountant               15    2
# Architect                64    9
# Business Analyst         65    6
# Chef                     54    5
# Chemist                  58    1
# Civil Engineer           28    3
# Consultant               67    5
# Content Writer          112    4
# Customer Support         39    2
# Data Scientist           36    6
# Digital Marketer         30    1
# Doctor                   62    4
# Educational Consultant   40    4
# Electrician              31    2
# Entrepreneur             62    1
# Finanancial Analyst      36    2
# Financial Analyst        32    4
# Graphic Designer         20    6
# HR Manager               72   12
# Investment Banker        10    1
# Judge                    36    6
# Lawyer                   43    5
# Manager                  39    3
# Marketing Manager        36    3
# Mechanical Engineer      26    4
# Pharmacist               74    1
# Pilot                    36    3
# Plumber                  32    3
# Research Analyst         13    2
# Researcher               43    2
# Sales Executive          30    2
# Software Engineer        33    1
# Teacher                 294   28
# Travel Consultant        45    1
# UX/UI Designer           24    2

# %%
update_project_name("Depression_Analysis.ipynb")
Ho = 'Profession does not have any significant relation with Target variable'
Ha =  'Profession have some significant relation with Target variable'

test_stat, pval, dof, _ = stats.chi2_contingency(chi2contingency)

if pval < 0.05:
    print('we reject the null hypothesis')
    print(Ha)
else:
    print('we fail to rejct the null hypothesis')
    print(Ho)
# Out:
# we fail to rejct the null hypothesis
# Profession does not have any significant relation with Target variable

# %% [markdown]
# Removing Profession value as it does not have a significant relation with our target variable aka Depression by performing a Chi-Square (Test Fail to reject the null hypothesis)

# %% [markdown]
# ### **DATA CLEANING**

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.drop(columns = ['Academic Pressure', 'Study Satisfaction', 'Work Pressure', 'Job Satisfaction', 'Profession'], inplace = True)

# %%
data.head()
# Out:
#       Name  Gender  Age       City Working Professional or Student  CGPA  \
# 0    Pooja  Female   37  Ghaziabad            Working Professional   0.0
# 1  Reyansh    Male   60     Kalyan            Working Professional   0.0
# 2    Manvi  Female   42     Bhopal            Working Professional   0.0
# 3     Isha  Female   44      Thane            Working Professional   0.0
# 4    Aarav    Male   48     Indore            Working Professional   0.0
#
#   Sleep Duration Dietary Habits Degree Have you ever had suicidal thoughts ?  \
# 0      7-8 hours       Moderate     MA                                    No
# 1      5-6 hours      Unhealthy  B.Com                                   Yes
# 2      5-6 hours       Moderate  M.Com                                    No
# 3      7-8 hours        Healthy     MD                                   Yes
# 4      7-8 hours       Moderate     BE                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0                 6                 2                               No
# 1                 0                 4                              Yes
# 2                 0                 2                               No
# 3                 1                 2                              Yes
# 4                 6                 5                              Yes
#
#   Depression  Work/Acadmic Pressure  Study/Job Satisfaction
# 0         No                    2.0                     4.0
# 1         No                    4.0                     3.0
# 2         No                    2.0                     3.0
# 3         No                    3.0                     5.0
# 4         No                    4.0                     3.0

# %%
# City is irrelevent column so we can drop it

data.drop(columns = ['City'], inplace = True)

# %%
data['Degree'].unique()
# Out:
# array(['MA', 'B.Com', 'M.Com', 'MD', 'BE', 'MCA', 'BA', 'LLM', 'BCA',
#        'Class 12', 'B.Ed', 'M.Tech', 'LLB', 'B.Arch', 'ME', 'MBA',
#        'M.Pharm', 'MBBS', 'PhD', 'BSc', 'MSc', 'MHM', 'BBA', 'BHM',
#        'B.Tech', 'M.Ed', 'B.Pharm'], dtype=object)

# %% [markdown]
# A lot of categories are present in the degree column, so we group them into schooling, undergraduate, postgraduate, and PhD.

# %%
education_mapping = {
    'Class 12': 'Schooling', 'B.Com': 'Undergraduate', 'BCA': 'Undergraduate', 'BA': 'Undergraduate', 
    'BBA': 'Undergraduate', 'BHM': 'Undergraduate', 'BSc': 'Undergraduate', 'B.Tech': 'Undergraduate', 
    'B.Pharm': 'Undergraduate', 'B.Arch': 'Undergraduate', 'BE': 'Undergraduate', 'BDS': 'Undergraduate',
    'MA': 'Postgraduate', 'M.Com': 'Postgraduate', 'M.Tech': 'Postgraduate', 'MBA': 'Postgraduate', 
    'MCA': 'Postgraduate', 'MSc': 'Postgraduate', 'PhD': 'PhD', 'MD': 'Postgraduate', 
    'M.Pharm': 'Postgraduate', 'LLM': 'Postgraduate', 'M.Ed': 'Postgraduate', 'ME': 'Postgraduate', 
    'MBBS': 'Undergraduate', 'LLB': 'Undergraduate', 'B.Ed': 'Undergraduate', 'BAMS': 'Undergraduate','MHM': 'Undergraduate'}

# %%
data['Degree'].value_counts()
# Out:
# Degree
# Class 12    275
# B.Com       115
# B.Ed        112
# MCA         108
# BCA         103
# MSc          95
# MBA          95
# BSc          94
# BBA          92
# BHM          90
# B.Arch       89
# BA           89
# B.Pharm      88
# M.Tech       85
# M.Pharm      85
# ME           84
# LLM          84
# BE           84
# LLB          82
# PhD          81
# MHM          81
# M.Ed         81
# MA           79
# MBBS         75
# MD           74
# B.Tech       71
# M.Com        65
# Name: count, dtype: int64

# %%
data['Degree'].map(education_mapping).value_counts()
# Out:
# Degree
# Undergraduate    1265
# Postgraduate      935
# Schooling         275
# PhD                81
# Name: count, dtype: int64

# %%
data['Degree'] = data['Degree'].map(education_mapping)

# %%
data.set_index('Name', inplace = True)

# %%
data.tail(4)
# Out:
#         Gender  Age Working Professional or Student  CGPA     Sleep Duration  \
# Name
# Pihu    Female   23            Working Professional   0.0  Less than 5 hours
# Sara    Female   24            Working Professional   0.0  Less than 5 hours
# Eshita  Female   56            Working Professional   0.0          7-8 hours
# Kiran     Male   18                         Student   6.7  More than 8 hours
#
#        Dietary Habits         Degree Have you ever had suicidal thoughts ?  \
# Name
# Pihu         Moderate   Postgraduate                                   Yes
# Sara         Moderate  Undergraduate                                   Yes
# Eshita        Healthy  Undergraduate                                    No
# Kiran       Unhealthy      Schooling                                    No
#
#         Work/Study Hours  Financial Stress Family History of Mental Illness  \
# Name
# Pihu                   8                 3                               No
# Sara                   4                 4                               No
# Eshita                 4                 5                              Yes
# Kiran                  6                 2                              Yes
#
#        Depression  Work/Acadmic Pressure  Study/Job Satisfaction
# Name
# Pihu          Yes                    3.0                     1.0
# Sara           No                    1.0                     4.0
# Eshita         No                    2.0                     3.0
# Kiran         Yes                    5.0                     3.0

# %% [markdown]
# ## **FEATURE ENCODING**

# %%
update_project_name("Depression_Analysis.ipynb")
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
le = LabelEncoder()

data['Depression'] = le.fit_transform(data['Depression'])
data['Gender'] = le.fit_transform(data['Gender'])
data['Family History of Mental Illness'] = le.fit_transform(data['Family History of Mental Illness'])
data['Working Professional or Student'] = le.fit_transform(data['Working Professional or Student'])
data['Have you ever had suicidal thoughts ?'] = le.fit_transform(data['Have you ever had suicidal thoughts ?'])

# %%
data['Sleep Duration'].value_counts()

dic = {'Less than 5 hours' : 0, '5-6 hours' : 1, '7-8 hours' : 2, 'More than 8 hours' : 3}  

data['Sleep Duration'] = data['Sleep Duration'].map(dic)

# %%
mapp = {'Healthy': 2, 'Unhealthy': 0, 'Moderate': 1}

data['Dietary Habits'] = data['Dietary Habits'].map(mapp)

# %%
mapdict = {'Schooling' : 0, 'Undergraduate': 1, 'Postgraduate': 2, 'PhD': 0}

data['Degree'] = data['Degree'].map(mapdict)

# %%
data.head(2)
# Out:
#          Gender  Age  Working Professional or Student  CGPA  Sleep Duration  \
# Name
# Pooja         0   37                                1   0.0               2
# Reyansh       1   60                                1   0.0               1
#
#          Dietary Habits  Degree  Have you ever had suicidal thoughts ?  \
# Name
# Pooja                 1       2                                      0
# Reyansh               0       1                                      1
#
#          Work/Study Hours  Financial Stress  Family History of Mental Illness  \
# Name
# Pooja                   6                 2                                 0
# Reyansh                 0                 4                                 1
#
#          Depression  Work/Acadmic Pressure  Study/Job Satisfaction
# Name
# Pooja             0                    2.0                     4.0
# Reyansh           0                    4.0                     3.0

# %% [markdown]
# ## **Feature Scaling**

# %%
sc = StandardScaler()

data_s = pd.DataFrame(sc.fit_transform(data), columns = data.columns, index = data.index)

# %%
data.head()
# Out:
#          Gender  Age  Working Professional or Student  CGPA  Sleep Duration  \
# Name
# Pooja         0   37                                1   0.0               2
# Reyansh       1   60                                1   0.0               1
# Manvi         0   42                                1   0.0               1
# Isha          0   44                                1   0.0               2
# Aarav         1   48                                1   0.0               2
#
#          Dietary Habits  Degree  Have you ever had suicidal thoughts ?  \
# Name
# Pooja                 1       2                                      0
# Reyansh               0       1                                      1
# Manvi                 1       2                                      0
# Isha                  2       2                                      1
# Aarav                 1       1                                      1
#
#          Work/Study Hours  Financial Stress  Family History of Mental Illness  \
# Name
# Pooja                   6                 2                                 0
# Reyansh                 0                 4                                 1
# Manvi                   0                 2                                 0
# Isha                    1                 2                                 1
# Aarav                   6                 5                                 1
#
#          Depression  Work/Acadmic Pressure  Study/Job Satisfaction
# Name
# Pooja             0                    2.0                     4.0
# Reyansh           0                    4.0                     3.0
# Manvi             0                    2.0                     3.0
# Isha              0                    3.0                     5.0
# Aarav             0                    4.0                     3.0

# %% [markdown]
# ## **TRAIN TEST SPLIT**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, cohen_kappa_score, accuracy_score, precision_score, recall_score, f1_score,roc_auc_score, roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, VotingClassifier, StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB

# %%
X = data_s.drop(columns = 'Depression')
Y = data['Depression']

# %%
X.isnull().sum()
# Out:
# Gender                                   0
# Age                                      0
# Working Professional or Student          0
# CGPA                                     0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Work/Acadmic Pressure                    0
# Study/Job Satisfaction                   0
# dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0, shuffle=True, stratify = Y)

print(f'''X_TRAIN SHAPE : {x_train.shape}
X_TEST SHAPE : {x_test.shape}
Y_TRAIN SHAPE : {y_train.shape}
Y_TEST SHAPE : {y_test.shape}''')
# Out:
# X_TRAIN SHAPE : (2044, 13)
# X_TEST SHAPE : (512, 13)
# Y_TRAIN SHAPE : (2044,)
# Y_TEST SHAPE : (512,)

# %%
update_project_name("Depression_Analysis.ipynb")

m = []
acc = []
pre = []
rec = []
f1 = []
kp = []
cf = []


def model_val(model,xtrain, ytrain, xtest, y_test):
    mod = model
    mod.fit(xtrain, ytrain)
    soft_pred = mod.predict_proba(xtest)[:,1]
    hard_pred = (soft_pred > 0.5).astype(int)

    print(f'''CLASSIFICATION REPORT : {classification_report(y_test, hard_pred)}
    CONFUSION MATRIX : {confusion_matrix(y_test, hard_pred)}
    Cohen Kappa Score : {cohen_kappa_score(y_test, hard_pred)}''')


    plt.figure(figsize = (10,5))
    fpr, tpr, _ = roc_curve(y_test, soft_pred)
    plt.plot(fpr, tpr,  label = model)
    plt.plot([0,1], [0,1], linestyle = '--', color = 'red')
    plt.title(f'ROC-AUC SCORE : {roc_auc_score(y_test, soft_pred)}')
    plt.legend()
    plt.show()


    response = input('Do you want to save this model ? (y/n) : ')
    if response.lower() == 'y':
        global Scoreline
        m.append(model)
        acc.append(accuracy_score(y_test, hard_pred))
        pre.append(precision_score(y_test, hard_pred))
        rec.append(recall_score(y_test, hard_pred))
        f1.append(f1_score(y_test, hard_pred))
        kp.append(cohen_kappa_score(y_test, hard_pred))
        cf.append(confusion_matrix(y_test, hard_pred))
        Scoreline = pd.DataFrame({'Model' : m, 'Accuracy' : acc, 'Precision' : pre, 'Recall' : rec, 'F1 Score' : f1, 'Kappa Score' : kp})
        
    else:
        pass

# %%
model_val(LogisticRegression(), x_train, y_train, x_test, y_test)
# Out:
# CLASSIFICATION REPORT :               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       421
#            1       0.94      0.93      0.94        91
#
#     accuracy                           0.98       512
#    macro avg       0.97      0.96      0.96       512
# weighted avg       0.98      0.98      0.98       512
#
#     CONFUSION MATRIX : [[416   5]
#  [  6  85]]
#     Cohen Kappa Score : 0.9261783673255387

# %%
Scoreline
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[271], line 1
# ----> 1 Scoreline
#
# NameError: name 'Scoreline' is not defined

# %%
model_val(KNeighborsClassifier(), x_train, y_train, x_test, y_test)
# Out:
# CLASSIFICATION REPORT :               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       421
#            1       0.86      0.69      0.77        91
#
#     accuracy                           0.93       512
#    macro avg       0.90      0.83      0.86       512
# weighted avg       0.92      0.93      0.92       512
#
#     CONFUSION MATRIX : [[411  10]
#  [ 28  63]]
#     Cohen Kappa Score : 0.7247389717325485

# %%
Scoreline
# Out:
# Empty DataFrame
# Columns: [Model, Accuracy, Precision, Recall, F1 Score, Kappa Score]
# Index: []

# %%
model_val(DecisionTreeClassifier(), x_train, y_train, x_test, y_test)
# Out:
# CLASSIFICATION REPORT :               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       421
#            1       0.79      0.77      0.78        91
#
#     accuracy                           0.92       512
#    macro avg       0.87      0.86      0.87       512
# weighted avg       0.92      0.92      0.92       512
#
#     CONFUSION MATRIX : [[402  19]
#  [ 21  70]]
#     Cohen Kappa Score : 0.7303915115452463

# %%
model_val(RandomForestClassifier(), x_train, y_train, x_test, y_test)
# Out:
# CLASSIFICATION REPORT :               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       421
#            1       0.96      0.79      0.87        91
#
#     accuracy                           0.96       512
#    macro avg       0.96      0.89      0.92       512
# weighted avg       0.96      0.96      0.96       512
#
#     CONFUSION MATRIX : [[418   3]
#  [ 19  72]]
#     Cohen Kappa Score : 0.8421126405203107

# %%
Scoreline
# Out:
# Empty DataFrame
# Columns: [Model, Accuracy, Precision, Recall, F1 Score, Kappa Score]
# Index: []
